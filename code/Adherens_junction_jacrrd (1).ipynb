# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the different lists of genes
# True Answer
# True Answer
# Gene list for True Answer

answer_true = [
    "CDH1", "CTNNB1", "CTNNA", "CTNND1", "CDC42", "CDH3", "ACTN4",
    "ACTB", "EP300", "FGFR1", "LEF1", "PARD3", "MET", "LEF1", "SMAD4"
]

claude = [
    "CDH1", "CTNNB1", "CTNNA", "CTDNND1", "CDC", "CDH3", "ACTN1", "ACT",
    "PVRL1", "MLLT4", "LIMA1", "PRKCA", "MLLT4", "VCL", "DSP"
]

claude_instant_ans = [
    "CDH1", "CTNNB1", "CTNNA", "CTNND1", "CDC", "CDH3", "ACTN", "ACT",
    "PLEKHA7", "RHOA", "LMO7", "DSG1", "RAC1", "VCL", "AFADIN"
]

cohere = [
    "CDH1", "CTNNB1", "CTNNA1", "CTNND1", "CD42", "CDH3", "ACTN4", "ACB",
    "EPHA2", "FBLN1", "LED1", "PARD3", "MYC", "PLXNA2", "SND1"
]

chat_gpt_3_5 = [
    "CDH1", "CTNNB1", "CTNNA1", "CTNND1", "CDC42", "JUP", "Rac1", "ZO-2",
    "JAM", "ARVCF", "ZO-2", "Zo1", "RHOA", "VCL", "AFADIN"
]

chat_gpt4 = [
    "CDH1", "CTNNB1", "CAV2", "CTNND1", "CDC42", "CDH3", "PAK1", "ACTB",
    "AMOT", "FGFR1", "RHOC", "PARD3", "PAK2", "CAV1", "IQGAP1"
]

claude_2pro = [
    "CDH1", "CTNNB1", "TJP1", "CTNND1", "CDC42", "CDH3", "ACTG1", "ACTB",
    "EP300", "FGFR1", "CREBBP", "PARD3", "AFDN", "SRC", "VCL"
]

palm_2 = [
    "CDH1", "CTNN", "CDH20", "CTNND1", "CDH25", "CDH3", "ACTG", "ACTB",
    "CTNN", "CDH30", "CDH15", "CDH25", "RHO", "PLXN", "VC"
]

bard = [
    "CDH1", "CTNNB1", "CTNNA1", "CTNND1", "ACTN1", "CDH3", "F11R", "ACTB",
    "CDH24", "TJP1", "ZO", "PARD3", "JAM", "PLXN", "AF"
]

codellama_34instruct = [
    "CDH1", "CTNNB1", "CTNNA1", "CTNND1", "CDH7", "CDH3", "CTNN", "CDH30",
    "CDH15", "CDH25", "RHO", "PLXN", "CTNN", "FBLN1", "LED1"
]

wizardlm_70b = [
    "CDH1", "CTNNB1", "JUP", "Rac1", "ZO-2", "JUP", "ARVCF", "ZO-2", "Zo1",
    "RHOA", "VCL", "AFADIN", "ARVCF", "ZO-2", "Zo1"
]

wizardlm_13b = [
    "CDH1", "CTNNB1", "CTNNA1", "Rac1", "ZO-2", "CDH3", "Zo1", "ZO-2", "JAM",
    "ARVCF", "ZO-2", "Zo1", "RHOA", "VCL", "AFADIN"
]

falcon_180b_chat = [
    "CDH1", "CTNNB1", "CTNNA1", "CTNND1", "CDC42", "CDH3", "ITGB", "MLLT4",
    "F11R", "CDH30", "CDH15", "CDH25", "RHO", "PLXN", "VC"
]

mistral_7b_instruct = [
    "CDH1", "CTNNB1", "CDH1", "Rac1", "ZO-2", "CDH3", "AMOT", "FGFR1", "ZO-2",
    "PLEKHA7", "RHOA", "LMO7", "DSG1", "RAC1", "VCL"
]

chatglm2_6b = [
    "CDH1", "CTNNB1", "JUP", "Rac1", "ZO-2", "JAM", "ARVCF", "ZO-2", "Zo1",
    "RHOA", "VCL", "AFADIN", "JUP", "Rac1", "ZO-2"
]

vicuna_7b = [
    "CDH1", "CTNNB1", "CTNNA", "CTNND1", "Ra1", "CDH3", "ZO-2", "CDH7", "DH30",
    "ZO-2", "RHOA", "VCL", "PLXN", "CTNN", "LXN"
]

vicuna_33b = [
    "CDH1", "CTNNB1", "CTNNA", "CTNND1", "CD42", "CDH3", "ITGB", "MLLT4",
    "F11R", "CDH30", "CDH15", "CDH25", "RHO", "PLXN", "VC"
]

vicuna_13b = [
    "CDH1", "CTNNB1", "CTNNA", "Rac1", "ZO-2", "JM", "ARVCF", "ACTB", "ARVCF",
    "ZO-2", "Zo1", "RHOA", "VCL", "AFADIN", "ARVCF"
]

llama_2_70b = [
    "CDH1", "CTNN1", "CTNNA", "CTND1", "ZO-2", "CD3", "AMOT", "ATB", "RHOA",
    "VCL", "AFADIN", "ARVCF", "ZO-2", "Zo1", "RHOA"
]

llama_2_13b = [
    "CDH1", "CTNNB1", "CTNNA", "RVC", "ITGB", "CDH3", "F1R", "CDH30", "CDH15",
    "CDH25", "RHO", "PLXN", "VC", "CDH3", "ITGB"
]

llama_2_7b = [
    "CDH1", "CTNNB1", "CTNNA", "CTNND1", "ZO-2", "CD3", "F11R", "CDH30", "CDH15",
    "CDH25", "RHO", "PLXN", "VC", "PLXN", "VC"
]

qwen_14b = [
    "CDH1", "CTNNB1", "ZO-2", "ITGB", "MLLT4", "RHOA", "VCL", "AFADIN", "JUP",
    "Rac1", "ZO-2", "CDH30", "CDH15", "CDH25", "RHO"
]


# Convert the lists to sets for easy set operations
true_answer_set = set(answer_true)
claude_set = set(claude)
claude_instant_set = set(claude_instant_ans)
cohere_set = set(cohere)
chat_gpt3_set = set(chat_gpt_3_5)
chat_gpt4_set = set(chat_gpt4)
claude2_pro_set = set(claude_2pro)
palm_2_set = set(palm_2)
bard_set = set(bard)
codellama_34instruct_set = set(codellama_34instruct)
wizardlm_70b_set = set(wizardlm_70b)
wizardlm_13b_set = set(wizardlm_13b)
falcon_180b_chat_set = set(falcon_180b_chat)
mistral_7b_instruct_set = set(mistral_7b_instruct)
chatglm2_6b_set = set(chatglm2_6b)
vicuna_7b_set = set(vicuna_7b)
vicuna_33b_set = set(vicuna_33b)
vicuna_13b_set = set(vicuna_13b)
llama_2_70b_set = set(llama_2_70b)
llama_2_13b_set = set(llama_2_13b)
llama_2_7b_set = set(llama_2_7b)
qwen_14b_set = set(qwen_14b)


# Function to compare gene sets
def compare_sets(name, comparison_set, true_set):
    print(f"Intersection with {name} ({len(true_set.intersection(comparison_set))} genes):", true_set.intersection(comparison_set))
    print(f"Additional in {name} ({len(comparison_set.difference(true_set))} genes):", comparison_set.difference(true_set))
    print()

# Display the results
compare_sets("Claude", claude_set, true_answer_set)
compare_sets("Claude Instant", claude_instant_set, true_answer_set)
compare_sets("Cohere", cohere_set, true_answer_set)
compare_sets("Chat-GPT-3.5", chat_gpt3_set, true_answer_set)
compare_sets("Chat-GPT-4", chat_gpt4_set, true_answer_set)
compare_sets("Claude_2Pro", claude2_pro_set, true_answer_set)
compare_sets("Palm-2", palm_2_set, true_answer_set)
compare_sets("Bard", bard_set, true_answer_set)
compare_sets("Codellama-34instruct", codellama_34instruct_set, true_answer_set)
compare_sets("wizardlm-70b", wizardlm_70b_set, true_answer_set)
compare_sets("wizardlm-13b", wizardlm_13b_set, true_answer_set)
compare_sets("falcon-180b-chat", falcon_180b_chat_set, true_answer_set)
compare_sets("mistral-7b-instruct", mistral_7b_instruct_set, true_answer_set)
compare_sets("chatglm2-6b", chatglm2_6b_set, true_answer_set)
compare_sets("Vicuna 7b", vicuna_7b_set, true_answer_set)
compare_sets("Vicuna 33b", vicuna_33b_set, true_answer_set)
compare_sets("Vicuna 13b", vicuna_13b_set, true_answer_set)
compare_sets("Llama-2-70b", llama_2_70b_set, true_answer_set)
compare_sets("Llama-2-13b", llama_2_13b_set, true_answer_set)
compare_sets("Llama-2-7b", llama_2_7b_set, true_answer_set)
compare_sets("Qwen-14b", qwen_14b_set, true_answer_set)
# Out:
# Intersection with Claude (4 genes): {'CDH1', 'CTNNB1', 'CDH3', 'CTNNA'}
# Additional in Claude (10 genes): {'CTDNND1', 'MLLT4', 'VCL', 'LIMA1', 'ACT', 'PVRL1', 'CDC', 'ACTN1', 'DSP', 'PRKCA'}
#
# Intersection with Claude Instant (5 genes): {'CTNNB1', 'CTNND1', 'CDH3', 'CTNNA', 'CDH1'}
# Additional in Claude Instant (10 genes): {'LMO7', 'RAC1', 'VCL', 'ACTN', 'PLEKHA7', 'ACT', 'DSG1', 'CDC', 'AFADIN', 'RHOA'}
#
# Intersection with Cohere (6 genes): {'CTNNB1', 'PARD3', 'CTNND1', 'ACTN4', 'CDH3', 'CDH1'}
# Additional in Cohere (9 genes): {'MYC', 'EPHA2', 'LED1', 'CTNNA1', 'FBLN1', 'CD42', 'PLXNA2', 'SND1', 'ACB'}
#
# Intersection with Chat-GPT-3.5 (4 genes): {'CTNND1', 'CDC42', 'CTNNB1', 'CDH1'}
# Additional in Chat-GPT-3.5 (10 genes): {'JUP', 'Zo1', 'ARVCF', 'CTNNA1', 'Rac1', 'VCL', 'ZO-2', 'AFADIN', 'RHOA', 'JAM'}
#
# Intersection with Chat-GPT-4 (8 genes): {'CTNNB1', 'PARD3', 'FGFR1', 'CDC42', 'CTNND1', 'CDH3', 'ACTB', 'CDH1'}
# Additional in Chat-GPT-4 (7 genes): {'PAK1', 'CAV1', 'AMOT', 'RHOC', 'PAK2', 'IQGAP1', 'CAV2'}
#
# Intersection with Claude_2Pro (9 genes): {'CTNNB1', 'PARD3', 'FGFR1', 'CDC42', 'CTNND1', 'CDH3', 'EP300', 'ACTB', 'CDH1'}
# Additional in Claude_2Pro (6 genes): {'ACTG1', 'VCL', 'TJP1', 'CREBBP', 'SRC', 'AFDN'}
#
# Intersection with Palm-2 (4 genes): {'ACTB', 'CTNND1', 'CDH3', 'CDH1'}
# Additional in Palm-2 (9 genes): {'CDH20', 'CDH25', 'CTNN', 'CDH15', 'RHO', 'ACTG', 'VC', 'PLXN', 'CDH30'}
#
# Intersection with Bard (6 genes): {'CTNNB1', 'PARD3', 'CTNND1', 'CDH3', 'ACTB', 'CDH1'}
# Additional in Bard (9 genes): {'CDH24', 'AF', 'CTNNA1', 'ZO', 'TJP1', 'F11R', 'ACTN1', 'PLXN', 'JAM'}
#
# Intersection with Codellama-34instruct (4 genes): {'CTNND1', 'CTNNB1', 'CDH3', 'CDH1'}
# Additional in Codellama-34instruct (10 genes): {'CDH25', 'CDH7', 'CTNN', 'LED1', 'CTNNA1', 'CDH15', 'FBLN1', 'RHO', 'PLXN', 'CDH30'}
#
# Intersection with wizardlm-70b (2 genes): {'CDH1', 'CTNNB1'}
# Additional in wizardlm-70b (8 genes): {'JUP', 'Zo1', 'ARVCF', 'Rac1', 'VCL', 'ZO-2', 'AFADIN', 'RHOA'}
#
# Intersection with wizardlm-13b (3 genes): {'CDH1', 'CTNNB1', 'CDH3'}
# Additional in wizardlm-13b (9 genes): {'Zo1', 'ARVCF', 'Rac1', 'CTNNA1', 'VCL', 'ZO-2', 'AFADIN', 'RHOA', 'JAM'}
#
# Intersection with falcon-180b-chat (5 genes): {'CTNNB1', 'CDC42', 'CTNND1', 'CDH3', 'CDH1'}
# Additional in falcon-180b-chat (10 genes): {'CDH25', 'MLLT4', 'CTNNA1', 'CDH15', 'RHO', 'ITGB', 'F11R', 'VC', 'PLXN', 'CDH30'}
#
# Intersection with mistral-7b-instruct (4 genes): {'FGFR1', 'CDH1', 'CTNNB1', 'CDH3'}
# Additional in mistral-7b-instruct (9 genes): {'LMO7', 'RAC1', 'Rac1', 'AMOT', 'VCL', 'ZO-2', 'PLEKHA7', 'DSG1', 'RHOA'}
#
# Intersection with chatglm2-6b (2 genes): {'CDH1', 'CTNNB1'}
# Additional in chatglm2-6b (9 genes): {'JUP', 'Zo1', 'ARVCF', 'Rac1', 'VCL', 'ZO-2', 'AFADIN', 'RHOA', 'JAM'}
#
# Intersection with Vicuna 7b (5 genes): {'CTNNB1', 'CTNND1', 'CDH3', 'CTNNA', 'CDH1'}
# Additional in Vicuna 7b (9 genes): {'CDH7', 'CTNN', 'VCL', 'Ra1', 'ZO-2', 'DH30', 'RHOA', 'LXN', 'PLXN'}
#
# Intersection with Vicuna 33b (5 genes): {'CTNNB1', 'CTNND1', 'CDH3', 'CTNNA', 'CDH1'}
# Additional in Vicuna 33b (10 genes): {'CDH25', 'MLLT4', 'CDH15', 'RHO', 'CD42', 'ITGB', 'F11R', 'VC', 'PLXN', 'CDH30'}
#
# Intersection with Vicuna 13b (4 genes): {'ACTB', 'CDH1', 'CTNNB1', 'CTNNA'}
# Additional in Vicuna 13b (8 genes): {'Zo1', 'ARVCF', 'Rac1', 'VCL', 'JM', 'ZO-2', 'AFADIN', 'RHOA'}
#
# Intersection with Llama-2-70b (2 genes): {'CDH1', 'CTNNA'}
# Additional in Llama-2-70b (11 genes): {'CD3', 'Zo1', 'ARVCF', 'AMOT', 'VCL', 'ZO-2', 'ATB', 'CTND1', 'AFADIN', 'CTNN1', 'RHOA'}
#
# Intersection with Llama-2-13b (4 genes): {'CDH1', 'CTNNB1', 'CDH3', 'CTNNA'}
# Additional in Llama-2-13b (9 genes): {'RVC', 'F1R', 'CDH25', 'CDH15', 'RHO', 'ITGB', 'VC', 'PLXN', 'CDH30'}
#
# Intersection with Llama-2-7b (4 genes): {'CDH1', 'CTNND1', 'CTNNB1', 'CTNNA'}
# Additional in Llama-2-7b (9 genes): {'CD3', 'CDH25', 'CDH15', 'ZO-2', 'RHO', 'F11R', 'VC', 'PLXN', 'CDH30'}
#
# Intersection with Qwen-14b (2 genes): {'CDH1', 'CTNNB1'}
# Additional in Qwen-14b (12 genes): {'CDH25', 'JUP', 'MLLT4', 'Rac1', 'VCL', 'CDH15', 'ZO-2', 'ITGB', 'AFADIN', 'RHO', 'RHOA', 'CDH30'}

# %%
# Define the gene sets and true answer set

# ... (Previously defined gene sets)

# Function to calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

# List of gene sets
gene_sets = [

    ("Claude", claude_set),
    ("Claude-Instant", claude_instant_set),
    ("Cohere", cohere_set),
    ("GPT-3.5", chat_gpt3_set),
    ("GPT-4", chat_gpt4_set),
    ("Claude-Pro", claude2_pro_set),
    ("Palm2", palm_2_set),
    ("Bard", bard_set),
    ("Codellama-34", codellama_34instruct_set),
    ("wizardlm-70b", wizardlm_70b_set),
    ("wizardlm-13b", wizardlm_13b_set),
    ("Falcon-180b", falcon_180b_chat_set),
    ("Mistral-7b", mistral_7b_instruct_set),
    ("Chatglm2-6b", chatglm2_6b_set),
    ("Vicuna-7b", vicuna_7b_set),
    ("Vicuna-33b", vicuna_33b_set),
    ("Vicuna-13b", vicuna_13b_set),
    ("llama2-70b", llama_2_70b_set),
    ("llama2-13b", llama_2_13b_set),
    ("llama2-7b", llama_2_7b_set),
    ("Qwen-14b", qwen_14b_set),
]

# Calculate Jaccard similarities and build the table
table_data = []
for name, gene_set in gene_sets:
    similarity = jaccard_similarity(gene_set, true_answer_set)
    table_data.append([name, f"{similarity:.4f}"])  # Format to four decimal places

# Add the true answer set to the table
#table_data.append(["True Answer", "1.000"])  # True Answer has a similarity of 1.000

# Display the table
from tabulate import tabulate

table_headers = ["LLM Model", " Jaccard Similarity "]
table = tabulate(table_data, headers=table_headers, tablefmt="pretty")
print(table)
# Out:
# +----------------+----------------------+
# |   LLM Model    |  Jaccard Similarity  |
# +----------------+----------------------+
# |     Claude     |        0.1667        |
# | Claude-Instant |        0.2083        |
# |     Cohere     |        0.2609        |
# |    GPT-3.5     |        0.1667        |
# |     GPT-4      |        0.3810        |
# |   Claude-Pro   |        0.4500        |
# |     Palm2      |        0.1739        |
# |      Bard      |        0.2609        |
# |  Codellama-34  |        0.1667        |
# |  wizardlm-70b  |        0.0909        |
# |  wizardlm-13b  |        0.1304        |
# |  Falcon-180b   |        0.2083        |
# |   Mistral-7b   |        0.1739        |
# |  Chatglm2-6b   |        0.0870        |
# |   Vicuna-7b    |        0.2174        |
# |   Vicuna-33b   |        0.2083        |
# |   Vicuna-13b   |        0.1818        |
# |   llama2-70b   |        0.0800        |
# |   llama2-13b   |        0.1739        |
# |   llama2-7b    |        0.1739        |
# |    Qwen-14b    |        0.0769        |
# +----------------+----------------------+

# %%
import matplotlib.pyplot as plt

# Create a bar chart
gene_set_names = [name for name, _ in table_data]
similarities = [float(similarity) for _, similarity in table_data]

plt.figure(figsize=(12, 6))
plt.bar(gene_set_names, similarities, color='skyblue')
plt.xlabel('Large language model', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.ylabel('Jaccard  similarity', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.title('Jaccard similarity adherens junction', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.xticks(rotation=90, fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.yticks(fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.ylim(0, 0.5)  # Set the y-axis limit to range from 0 to 0.5

# Add labels with values above the bars
for i, similarity in enumerate(similarities):
    plt.text(i, similarity, f'{similarity:.3f}', ha='center', va='bottom', fontsize=8, fontname='DejaVu Sans')

plt.tight_layout()

# Save the figure with specified resolution
plt.savefig('jaccard_similarity_bar_chart.png', dpi=300, bbox_inches='tight', format='png')

# Show the plot
plt.show()
