# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the different lists of genes
# True Answer
# Gene Lists
gene_list_answer_true = ["GJA1", "GJB1", "GJC1", "GJD2", "ADCY1", "ADRB1", "CSNK1D", "DRD1", "EGF", "EGFR", "GNA11", "PRKCA", "GJA5", "HRAS", "MAP2K1"]

claude = ["GJA1", "GJB1", "GJC1", "GJD1", "CX33", "CX36", "CX45", "GJA4", "CX59", "CX62", "GJA8", "CX40", "GJA5", "CX47", "ABC"]

claude_instant_ans = ["GJA1", "GJB1", "GJC1", "GJC3", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "SLC2", "GJB", "GJA5", "C24A3", "LIM"]

cohere = ["GJA1", "GJB1", "GJC1", "GJD2", "GJC3", "SLC24A6", "ITGB1", "GJA8", "CL3", "CLCN3", "CLCN1", "GJB6", "GJA5", "C24A3", "GJA10"]

chat_gpt_3_5 = ["GJA1", "GJB1", "GJC1", "GJA12", "GJB10", "GJB7", "GJA7", "GJB", "GJB2", "GJB3", "GJAC", "GJA8", "GJA5", "GDD", "GJAA"]

chat_gpt4 = ["GJA1", "GJB1", "GJC1", "GJD2", "GJB6", "GJB8", "GJB3", "GJA4", "GJB", "GJDD", "GJB", "PRKCA", "GJA5", "CLCN", "GJA"]

claude_2pro = ["GJA1", "GJB1", "GJC1", "GJD2", "GJB6", "GJB8", "GJB3", "GJA4", "GJB", "GJDD", "GJB", "PRKG1", "GJA5", "HRAS", "GJA"]

palm_2 = ["GJA1", "GJB1", "GJC1", "GJ2", "CX33", "PRPH2", "LIM", "CLP", "COROM1", "CLSC3", "BCAP3", "CA", "COPORS", "COROS", "CORODS"]

bard = ["GJA1", "GJB1", "GJC1", "GJD2", "PANXI", "PANX2", "PANX3", "GJML", "GJB", "SLC24A6", "ITGB1", "GJA8", "GJA5", "CLCN", "GJA"]

codellama_34instruct = ["GJA1", "GJB1", "GJC1", "GJD2", "GJC3", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "SLC2", "GJA5", "SLC2", "GJB"]

wizardlm_70b = ["GJA1", "GJB1", "GJC1", "GJA1", "GJB1", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "SLC2", "GJA5", "SLC2", "GJB"]

wizardlm_13b = ["GJA1", "GJB1", "GJC1", "abc", "GJB7", "GJA7", "GJB", "GJB2", "GJB3", "GJAC", "GJB7", "xyz", "GJA5", "GJB7", "GJA7"]

falcon_180b_chat = ["GJA1", "GJB1", "GJC1", "GJD2", "GJC3", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "SLC2", "GJA5", "CLCN", "GJA"]

mistral_7b_instruct = ["GJA1", "GJB1", "GJC1", "GJC3", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "GJC3", "SLC24A3", "GJA5", "GJB7", "GJA7"]

chatglm2_6b = ["GJA1", "GJB1", "GJC1", "GJB10", "GJB7", "GJA7", "GJB", "GJB2", "GJB3", "GJAC", "GJA8", "GJB10", "GJB7", "GJA7", "GJB"]

vicuna_7b = ["GJA1", "GJB1", "GJC1", "GJB1", "SLC24A3", "SLC24A6", "PRPH2", "LIM2", "CX62", "GJB6", "SLC2", "GJB1", "GJA5", "GJA7", "GJB"]

vicuna_33b = ["GJA1", "GJB1", "GJC1", "GJB1", "GJB1", "SLC24A3", "SLC24A6", "PRPH2", "EGF", "SLC24A6", "ITGB1", "GJA8", "GJA5", "CLCN", "GJA"]

vicuna_13b = ["GJA1", "GJB1", "GJC1", "GJB1", "GJB1", "GJA7", "GJB", "GJB2", "GJB3", "GJAC", "GJA8", "GJB10", "GJB7", "GJA7", "GJB"]

llama_2_70b = ["GJA1", "GJB1", "GJC1", "GJB7", "GJA7", "GJB", "GJB2", "GJB3", "GJAC", "GJB7", "xyz", "GJB7", "GJA5", "CLCN", "GJA"]

llama_2_13b = ["GJA1", "GJB1", "GJC1", "GJ2", "GJB1", "GJC1", "GJB", "GJB2", "GJB3", "GJAC", "GJA8", "GJB10", "GJA5", "GJA7", "GJB"]

llama_2_7b = ["GJA1", "GJB1", "GJC1", "GJD2", "GJC1", "GJB", "GJB2", "GJB3", "GJAC", "GJA8", "GJB10", "GJC1", "GJA5", "CLCN", "GJA"]

qwen_14b = ["GJA1", "GJB", "GJC", "GJB10", "G7", "GJA7", "GJB", "GJ2", "GJB3", "GJAC", "GJA8", "GA5", "GDD", "GJAA", "GJB10"]

# Convert the lists to sets for easy set operations
# Convert the lists to sets for easy set operations
true_answer_set = set(gene_list_answer_true)
claude_set = set(claude)
claude_instant_set = set(claude_instant_ans)
cohere_set = set(cohere)
chat_gpt3_set = set(chat_gpt_3_5)
chat_gpt4_set = set(chat_gpt4)
claude2_pro_set = set(claude_2pro)
palm_2_set = set(palm_2)
bard_set = set(bard)
codellama_34instruct_set = set(codellama_34instruct)
wizardlm_70b_set = set(wizardlm_70b)
wizardlm_13b_set = set(wizardlm_13b)
falcon_180b_chat_set = set(falcon_180b_chat)
mistral_7b_instruct_set = set(mistral_7b_instruct)
chatglm2_6b_set = set(chatglm2_6b)
vicuna_7b_set = set(vicuna_7b)
vicuna_33b_set = set(vicuna_33b)
vicuna_13b_set = set(vicuna_13b)
llama_2_70b_set = set(llama_2_70b)
llama_2_13b_set = set(llama_2_13b)
llama_2_7b_set = set(llama_2_7b)
qwen_14b_set = set(qwen_14b)


# Function to compare gene sets
def compare_sets(name, comparison_set, true_set):
    print(f"Intersection with {name} ({len(true_set.intersection(comparison_set))} genes):", true_set.intersection(comparison_set))
    print(f"Additional in {name} ({len(comparison_set.difference(true_set))} genes):", comparison_set.difference(true_set))
    print()

# Display the results
compare_sets("Claude", claude_set, true_answer_set)
compare_sets("Claude Instant", claude_instant_set, true_answer_set)
compare_sets("Cohere", cohere_set, true_answer_set)
compare_sets("Chat-GPT-3.5", chat_gpt3_set, true_answer_set)
compare_sets("Chat-GPT-4", chat_gpt4_set, true_answer_set)
compare_sets("Claude_2Pro", claude2_pro_set, true_answer_set)
compare_sets("Palm-2", palm_2_set, true_answer_set)
compare_sets("Bard", bard_set, true_answer_set)
compare_sets("Codellama-34instruct", codellama_34instruct_set, true_answer_set)
compare_sets("wizardlm-70b", wizardlm_70b_set, true_answer_set)
compare_sets("wizardlm-13b", wizardlm_13b_set, true_answer_set)
compare_sets("falcon-180b-chat", falcon_180b_chat_set, true_answer_set)
compare_sets("mistral-7b-instruct", mistral_7b_instruct_set, true_answer_set)
compare_sets("chatglm2-6b", chatglm2_6b_set, true_answer_set)
compare_sets("vicuna_7b", vicuna_7b_set, true_answer_set)
compare_sets("vicuna_33b", vicuna_33b_set, true_answer_set)
compare_sets("vicuna_13b", vicuna_13b_set, true_answer_set)
compare_sets("llama_2_70b", llama_2_70b_set, true_answer_set)
compare_sets("llama_2_13b", llama_2_13b_set, true_answer_set)
compare_sets("llama_2_7b", llama_2_7b_set, true_answer_set)
compare_sets("qwen_14b", qwen_14b_set, true_answer_set)
# Out:
# Intersection with Claude (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in Claude (11 genes): {'CX33', 'CX36', 'GJA4', 'GJA8', 'CX59', 'CX40', 'CX47', 'CX62', 'GJD1', 'ABC', 'CX45'}
#
# Intersection with Claude Instant (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in Claude Instant (11 genes): {'GJC3', 'SLC24A6', 'GJB', 'PRPH2', 'GJB6', 'CX62', 'LIM', 'LIM2', 'C24A3', 'SLC24A3', 'SLC2'}
#
# Intersection with Cohere (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2'}
# Additional in Cohere (10 genes): {'GJC3', 'GJA8', 'SLC24A6', 'CL3', 'GJB6', 'CLCN3', 'GJA10', 'CLCN1', 'C24A3', 'ITGB1'}
#
# Intersection with Chat-GPT-3.5 (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in Chat-GPT-3.5 (11 genes): {'GJA12', 'GJB7', 'GDD', 'GJA8', 'GJB3', 'GJB', 'GJB10', 'GJB2', 'GJAC', 'GJAA', 'GJA7'}
#
# Intersection with Chat-GPT-4 (6 genes): {'GJC1', 'GJA5', 'PRKCA', 'GJA1', 'GJB1', 'GJD2'}
# Additional in Chat-GPT-4 (8 genes): {'GJA4', 'CLCN', 'GJB3', 'GJB', 'GJB6', 'GJA', 'GJDD', 'GJB8'}
#
# Intersection with Claude_2Pro (6 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2', 'HRAS'}
# Additional in Claude_2Pro (8 genes): {'GJA4', 'GJB3', 'GJB', 'GJB6', 'GJA', 'PRKG1', 'GJDD', 'GJB8'}
#
# Intersection with Palm-2 (3 genes): {'GJB1', 'GJC1', 'GJA1'}
# Additional in Palm-2 (12 genes): {'CX33', 'COPORS', 'BCAP3', 'PRPH2', 'CLSC3', 'CLP', 'LIM', 'COROM1', 'GJ2', 'CORODS', 'COROS', 'CA'}
#
# Intersection with Bard (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2'}
# Additional in Bard (10 genes): {'SLC24A6', 'GJA8', 'CLCN', 'GJB', 'PANX3', 'PANX2', 'GJML', 'PANXI', 'ITGB1', 'GJA'}
#
# Intersection with Codellama-34instruct (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2'}
# Additional in Codellama-34instruct (9 genes): {'GJC3', 'SLC24A6', 'GJB', 'PRPH2', 'GJB6', 'CX62', 'LIM2', 'SLC24A3', 'SLC2'}
#
# Intersection with wizardlm-70b (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in wizardlm-70b (8 genes): {'SLC24A6', 'GJB', 'PRPH2', 'GJB6', 'CX62', 'LIM2', 'SLC24A3', 'SLC2'}
#
# Intersection with wizardlm-13b (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in wizardlm-13b (8 genes): {'GJB7', 'xyz', 'GJB3', 'GJB', 'abc', 'GJB2', 'GJAC', 'GJA7'}
#
# Intersection with falcon-180b-chat (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2'}
# Additional in falcon-180b-chat (10 genes): {'GJC3', 'SLC24A6', 'CLCN', 'PRPH2', 'GJB6', 'CX62', 'LIM2', 'SLC24A3', 'SLC2', 'GJA'}
#
# Intersection with mistral-7b-instruct (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in mistral-7b-instruct (9 genes): {'GJB7', 'GJC3', 'SLC24A6', 'PRPH2', 'GJB6', 'CX62', 'SLC24A3', 'LIM2', 'GJA7'}
#
# Intersection with chatglm2-6b (3 genes): {'GJB1', 'GJC1', 'GJA1'}
# Additional in chatglm2-6b (8 genes): {'GJB7', 'GJA8', 'GJB3', 'GJB', 'GJB10', 'GJB2', 'GJAC', 'GJA7'}
#
# Intersection with vicuna_7b (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in vicuna_7b (9 genes): {'SLC24A6', 'GJB', 'PRPH2', 'GJB6', 'CX62', 'LIM2', 'SLC24A3', 'SLC2', 'GJA7'}
#
# Intersection with vicuna_33b (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'EGF'}
# Additional in vicuna_33b (7 genes): {'SLC24A6', 'GJA8', 'CLCN', 'PRPH2', 'SLC24A3', 'ITGB1', 'GJA'}
#
# Intersection with vicuna_13b (3 genes): {'GJB1', 'GJC1', 'GJA1'}
# Additional in vicuna_13b (8 genes): {'GJB7', 'GJA8', 'GJB3', 'GJB', 'GJB10', 'GJB2', 'GJAC', 'GJA7'}
#
# Intersection with llama_2_70b (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in llama_2_70b (9 genes): {'GJB7', 'CLCN', 'xyz', 'GJB3', 'GJB', 'GJB2', 'GJAC', 'GJA', 'GJA7'}
#
# Intersection with llama_2_13b (4 genes): {'GJB1', 'GJC1', 'GJA1', 'GJA5'}
# Additional in llama_2_13b (8 genes): {'GJA8', 'GJB3', 'GJB', 'GJ2', 'GJB10', 'GJB2', 'GJAC', 'GJA7'}
#
# Intersection with llama_2_7b (5 genes): {'GJC1', 'GJA5', 'GJA1', 'GJB1', 'GJD2'}
# Additional in llama_2_7b (8 genes): {'GJA8', 'CLCN', 'GJB3', 'GJB', 'GJB10', 'GJB2', 'GJAC', 'GJA'}
#
# Intersection with qwen_14b (1 genes): {'GJA1'}
# Additional in qwen_14b (12 genes): {'GJB10', 'GDD', 'GJA8', 'GJB3', 'GJB', 'GJ2', 'G7', 'GA5', 'GJAC', 'GJAA', 'GJA7', 'GJC'}

# %%
# Define the gene sets and true answer set

# ... (Previously defined gene sets)

# Function to calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

# List of gene sets
gene_sets = [
    ("Claude", claude_set),
    ("Claude Instant", claude_instant_set),
    ("Cohere", cohere_set),
    ("Chat-GPT-3.5", chat_gpt3_set),
    ("Chat-GPT-4", chat_gpt4_set),
    ("Claude_2Pro", claude2_pro_set),
    ("Palm-2", palm_2_set),
    ("Bard", bard_set),
    ("Codellama-34instruct", codellama_34instruct_set),
    ("wizardlm-70b", wizardlm_70b_set),
    ("wizardlm-13b", wizardlm_13b_set),
    ("falcon-180b-chat", falcon_180b_chat_set),
    ("mistral-7b-instruct", mistral_7b_instruct_set),
    ("chatglm2-6b", chatglm2_6b_set),
    ("vicuna_7b", vicuna_7b_set),
    ("vicuna_33b", vicuna_33b_set),
    ("vicuna_13b", vicuna_13b_set),
    ("llama_2_70b", llama_2_70b_set),
    ("llama_2_13b", llama_2_13b_set),
    ("llama_2_7b", llama_2_7b_set),
    ("qwen_14b", qwen_14b_set)
]


# Calculate Jaccard similarities and build the table
table_data = []
for name, gene_set in gene_sets:
    similarity = jaccard_similarity(gene_set, true_answer_set)
    table_data.append([name, f"{similarity:.4f}"])  # Format to four decimal places

# Add the true answer set to the table
#table_data.append(["True Answer", "1.000"])  # True Answer has a similarity of 1.000

# Display the table
from tabulate import tabulate

table_headers = ["LLM Model", "Jaccard Similarity"]
table = tabulate(table_data, headers=table_headers, tablefmt="pretty")
print(table)
# Out:
# +----------------------+--------------------+
# |      LLM Model       | Jaccard Similarity |
# +----------------------+--------------------+
# |        Claude        |       0.1538       |
# |    Claude Instant    |       0.1538       |
# |        Cohere        |       0.2000       |
# |     Chat-GPT-3.5     |       0.1538       |
# |      Chat-GPT-4      |       0.2609       |
# |     Claude_2Pro      |       0.2609       |
# |        Palm-2        |       0.1111       |
# |         Bard         |       0.2000       |
# | Codellama-34instruct |       0.2083       |
# |     wizardlm-70b     |       0.1739       |
# |     wizardlm-13b     |       0.1739       |
# |   falcon-180b-chat   |       0.2000       |
# | mistral-7b-instruct  |       0.1667       |
# |     chatglm2-6b      |       0.1304       |
# |      vicuna_7b       |       0.1667       |
# |      vicuna_33b      |       0.2273       |
# |      vicuna_13b      |       0.1304       |
# |     llama_2_70b      |       0.1667       |
# |     llama_2_13b      |       0.1739       |
# |      llama_2_7b      |       0.2174       |
# |       qwen_14b       |       0.0370       |
# +----------------------+--------------------+

# %%
import matplotlib.pyplot as plt

# Create a bar chart
gene_set_names = [name for name, _ in table_data]
similarities = [float(similarity) for _, similarity in table_data]

plt.figure(figsize=(12, 6))
plt.bar(gene_set_names, similarities, color='skyblue')
plt.xlabel('Large language model', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.ylabel('Jaccard  similarity', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.title('Jaccard similarity gap junction', fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.xticks(rotation=90, fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.yticks(fontsize=8, fontname='DejaVu Sans', weight='bold')
plt.ylim(0, 0.5)  # Set the y-axis limit to range from 0 to 0.5

# Add labels with values above the bars
for i, similarity in enumerate(similarities):
    plt.text(i, similarity, f'{similarity:.3f}', ha='center', va='bottom', fontsize=8, fontname='DejaVu Sans')

plt.tight_layout()

# Save the figure with specified resolution
plt.savefig('jaccard_similarity_bar_chart.png', dpi=300, bbox_inches='tight', format='png')

# Show the plot
plt.show()
